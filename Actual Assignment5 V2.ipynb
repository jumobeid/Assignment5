# %%
def visualize(filename):
    "Plot the subplot"
    data = pd.read_csv(filepath_or_buffer = filename)
    a_list = list(range(0, 40))
    x = np.array(a_list)
    i = list(range(0, 3))
    for m in filename[16:17]:
            data_features_plot = pd.DataFrame({'Average':data.mean(axis=0),'Max':data.max(axis=0),'Min':data.min(axis=0)})
            data_features_plot.plot()
            plt.title("dataset" + filename[16:17])
            matplotlib.pyplot.show()
            
    for i,name,y in [(1,'Average', data.mean(axis=0)),
                    (2,'Max', data.max(axis=0)),
                    (3,'Min', data.min(axis=0))]: 
       
            #print(x)
            #print(y)
        if i == 1:
            select_color = "yellow"
        elif i == 2:
            select_color = "Green"
        else: 
            select_color = "red"
       
        plt.subplot(4,3,i)
        plt.plot(x,y ,color= select_color)
        plt.title("dataset" + filename[16:17])
        plt.xlabel("Feature")
        plt.ylabel(name)
        plt.grid()
        matplotlib.pyplot.show()
        
    #plt.legend(name)

# %%
def identify_issues(filename):
    list_max= []
    "Print the descriptive statistics"
    data = pd.read_csv(filepath_or_buffer = filename)
    list_max = data.max(axis=0)
    sum_min = sum(data.min(axis=0))
    #print (sum_min)
    #print (list_max[0])
    #print (list_max[20])
    if (list_max[0] != 0 or list_max[20] != 20) and sum_min !=0:
           print("Dataset looks good")
    elif  sum_min == 0:
           print("Why is this happening")
    else:
           print("I doubt the integrity of this data set")

# %%
import glob
import numpy 
import matplotlib
import pandas as pd
import matplotlib.pyplot 
import matplotlib.pyplot as plt
import numpy as np

dataset = sorted(glob.glob(r'C:\Python\data*.csv'))
print(dataset)
# Out:
# ['C:\\Python\\data-01.csv', 'C:\\Python\\data-02.csv', 'C:\\Python\\data-03.csv', 'C:\\Python\\data-04.csv', 'C:\\Python\\dataset.csv']

# %%
for datasets in dataset[:4]:
    print("\n")
    print(datasets)
    visualize(datasets)
    identify_issues(datasets)
# Out:
# C:\Python\data-01.csv
# I doubt the integrity of this data set
#
#
# C:\Python\data-02.csv
# Dataset looks good
#
#
# C:\Python\data-03.csv
# Why is this happening
#
#
# C:\Python\data-04.csv
# I doubt the integrity of this data set
